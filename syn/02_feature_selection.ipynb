# %%
# =============================================================================
# SYN FEATURE IMPORTANCE ANALYSIS
# INPUT  : syn_clean.csv
# OUTPUT : syn_feature_importance.csv
# =============================================================================

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

print("="*80)
print("LOAD DATASET")
print("="*80)

df = pd.read_csv(
    r"I:\TA\syn\syn_clean.csv"
)

print(df.shape)

# =============================================================================
# SPLIT FEATURE DAN LABEL
# =============================================================================

X = df.drop(
    columns=["Label"]
)

y = df["Label"]

print("\nFeature Count :", X.shape[1])

# =============================================================================
# TRAIN TEST SPLIT
# =============================================================================

X_train, X_test, y_train, y_test = train_test_split(

    X,
    y,

    test_size=0.2,

    stratify=y,

    random_state=42

)

# =============================================================================
# RANDOM FOREST
# =============================================================================

print("\nTraining RF...")

rf = RandomForestClassifier(

    n_estimators=200,

    max_depth=15,

    min_samples_split=5,

    min_samples_leaf=2,

    n_jobs=-1,

    random_state=42

)

rf.fit(
    X_train,
    y_train
)

# =============================================================================
# FEATURE IMPORTANCE
# =============================================================================

importance_df = pd.DataFrame({

    "Feature": X.columns,
    "Importance": rf.feature_importances_

})

importance_df = importance_df.sort_values(

    by="Importance",
    ascending=False

)

print("\n")
print("="*80)
print("TOP 30 FEATURES")
print("="*80)

print(
    importance_df.head(30)
)

# =============================================================================
# SAVE
# =============================================================================

importance_df.to_csv(

    r"I:\TA\syn\syn_feature_importance.csv",

    index=False

)

print("\nSaved : syn_feature_importance.csv")
# Out:
# ================================================================================
# LOAD DATASET
# ================================================================================
# (62028, 82)
#
# Feature Count : 81
#
# Training RF...
#
#
# ================================================================================
# TOP 30 FEATURES
# ================================================================================
#                         Feature  Importance
# 68       Init_Win_bytes_forward    0.111745
# 80                      Inbound    0.111202
# 49               ACK Flag Count    0.110694
# 1              Destination Port    0.092646
# 50               URG Flag Count    0.049782
# 44       Packet Length Variance    0.036752
# 43            Packet Length Std    0.036170
# 8         Fwd Packet Length Max    0.035123
# 51               CWE Flag Count    0.030412
# 42           Packet Length Mean    0.028698
# 10       Fwd Packet Length Mean    0.027940
# 41            Max Packet Length    0.025096
# 65            Subflow Fwd Bytes    0.023583
# 6   Total Length of Fwd Packets    0.022416
# 0                   Source Port    0.021709
# 16                 Flow Bytes/s    0.020079
# 69      Init_Win_bytes_backward    0.018341
# 54          Average Packet Size    0.017869
# 9         Fwd Packet Length Min    0.015027
# 17               Flow Packets/s    0.014989
# 55         Avg Fwd Segment Size    0.014059
# 40            Min Packet Length    0.013931
# 70             act_data_pkt_fwd    0.013404
# 36            Fwd Header Length    0.011464
# 64          Subflow Fwd Packets    0.009852
# 18                Flow IAT Mean    0.008456
# 3                 Flow Duration    0.007893
# 38                Fwd Packets/s    0.007434
# 14       Bwd Packet Length Mean    0.006547
# 56         Avg Bwd Segment Size    0.006491
#
# Saved : syn_feature_importance.csv
